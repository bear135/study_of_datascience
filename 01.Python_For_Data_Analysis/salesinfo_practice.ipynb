# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
## sns.set(style='whitegrid')
sns.set(style='darkgrid')
# %matplotlib inline

# %%
df_sales = pd.read_excel('D:\sales_info.xlsx')

# %%
df_sales.head()
# Out:
#        ID       product        model    price      chanel          type  \
# 0  pnd022  Refrigerator   SRT756BSLE  1399000  Department          cash
# 1  pnd101            TV  UN46C8000XF  4450000      Himart  card-onetime
# 2  pnd278    Cell-phone    SHW-M100S   970000      Online  card-onetime
# 3  pnd171        Washer   WR-PD179UB  1450000  Department   card-divide
# 4  pnd050  Refrigerator   SRT746ABZF  3015000  Department     cashncard
#
#   purchase_date name     sex  age     area  join_date  no
# 0    2007-01-01  김도빈    male   38    Seoul 2008-02-10   1
# 1    2007-01-02  박진수    male   45  Gyunggi 2006-11-16   1
# 2    2007-01-03  최윤희  female   24  Gangwon 2006-12-15   1
# 3    2007-01-04  이기영    male   33  Jeonnam 2007-01-04   1
# 4    2007-01-05  김지수  female   28  Jeonbuk 2006-11-18   1

# %%
sns.catplot(data = df_sales, x = 'product', y = 'price', kind = 'box')

# %%
sns.catplot(data = df_sales, x = 'product', y = 'price', kind = 'bar', hue = 'sex')

# %%
sns.catplot(data = df_sales, x = 'product', y = 'price', kind = 'bar', hue = 'area')

# %%
sns.catplot(data = df_sales, x = 'product', y = 'price', kind = 'bar', hue = 'type')

# %%
sns.catplot(data = df_sales, x = 'type', y = 'price', kind = 'bar', hue = 'sex')
