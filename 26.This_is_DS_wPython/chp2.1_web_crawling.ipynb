# %% [markdown]
# ### Chapter 2.1 웹 크롤링으로 기초 데이터 수집하기

# %%
# !pip install beautifulsoup4 lxml cloudscraper
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\youngboo.choi\anaconda3.1\lib\site-packages (4.6.0)
# Requirement already satisfied: lxml in c:\users\youngboo.choi\anaconda3.1\lib\site-packages (4.6.3)
# Collecting cloudscraper
#   Using cached cloudscraper-1.2.58-py2.py3-none-any.whl (96 kB)
# Collecting requests-toolbelt>=0.9.1
#   Using cached requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\youngboo.choi\anaconda3.1\lib\site-packages (from cloudscraper) (2.4.7)
# Requirement already satisfied: requests>=2.9.2 in c:\users\youngboo.choi\anaconda3.1\lib\site-packages (from cloudscraper) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\youngboo.choi\anaconda3.1\lib\site-packages (from requests>=2.9.2->cloudscraper) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\youngboo.choi\anaconda3.1\lib\site-packages (from requests>=2.9.2->cloudscraper) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\youngboo.choi\anaconda3.1\lib\site-packages (from requests>=2.9.2->cloudscraper) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\youngboo.choi\anaconda3.1\lib\site-packages (from requests>=2.9.2->cloudscraper) (4.0.0)
# Installing collected packages: requests-toolbelt, cloudscraper
# Successfully installed cloudscraper-1.2.58 requests-toolbelt-0.9.1

# %%
import pandas as pd 
import re
import cloudscraper
from bs4 import BeautifulSoup

# %%
# 크롤링할 사이트 주소를 정의합니다.
source_url = "https://namu.wiki/RecentChanges"

# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
scraper = cloudscraper.create_scraper()
req = scraper.get(source_url)
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"

page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%EC%9C%A0%EC%83%81%EC%B2%A0
# https://namu.wiki/w/2022%20FIFA%20%EC%9B%94%EB%93%9C%EC%BB%B5%20%EC%B9%B4%ED%83%80%EB%A5%B4/%EC%A7%80%EC%97%AD%EC%98%88%EC%84%A0(%EC%95%84%EC%8B%9C%EC%95%84)/2%EC%B0%A8%EC%98%88%EC%84%A0/B%EC%A1%B0
# https://namu.wiki/w/KBO%20%EC%98%AC%EC%8A%A4%ED%83%80%EC%A0%84/2021%EB%85%84
# https://namu.wiki/w/%EB%9D%BC%EB%8F%88(%EB%AA%AC%EC%8A%A4%ED%84%B0%EB%B2%84%EC%8A%A4)
# https://namu.wiki/w/%EB%85%B8%ED%99%8D%EC%B2%A0

# %%
## 페이지내 텍스트 확인 
req = scraper.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text)
print("\n")
print(category.text)
print("\n")
print(content_corpus)
# Out:
# 유상철
#
#
# 1971년 출생1994년 데뷔2021년 사망췌장암으로 죽은 인물은평구 출신 인물문화 류씨경신고등학교(서울) 출신건국대학교 출신대한민국의 축구선수대한민국의 축구감독미드필더공격수수비수축구 해설자축구행정가대한민국의 개신교 신자/ㅇ울산 현대/은퇴, 이적요코하마 F. 마리노스/은퇴, 이적가시와 레이솔/은퇴, 이적대전 시티즌/역대 감독전남 드래곤즈/역대 감독인천 유나이티드 FC/역대 감독대한민국의 FIFA 월드컵 참가 선수1998 FIFA 월드컵 프랑스 참가 선수2002 FIFA 월드컵 한국/일본 참가 선수1996 AFC 아시안컵 아랍에미리트 참가 선수2000 AFC 아시안컵 레바논 참가 선수2000 CONCACAF 골드컵 참가 선수2002 CONCACAF 골드컵 참가 선수2001 FIFA 컨페더레이션스컵 한국/일본 참가 선수FIFA 센추리 클럽 가입 선수대한민국의 올림픽 축구 참가 선수2004 아테네 올림픽 참가 선수
#
#
#    은(는) 여기로 연결됩니다. 정치인에 대한 내용은 류상철 문서를의 번 문단을의  부분을, 에 대한 내용은  문서를의 번 문단을의 번 문단을의  부분을의  부분을, 에 대한 내용은  문서를의 번 문단을의 번 문단을의  부분을의  부분을, 에 대한 내용은  문서를의 번 문단을의 번 문단을의  부분을의  부분을, 에 대한 내용은  문서를의 번 문단을의 번 문단을의  부분을의  부분을, 에 대한 내용은  문서를의 번 문단을의 번 문단을의  부분을의  부분을, 에 대한 내용은  문서를의 번 문단을의 번 문단을의  부분을의  부분을, 에 대한 내용은  문서를의 번 문단을의 번 문단을의  부분을의  부분을, 에 대한 내용은  문서를의 번 문단을의 번 문단을의  부분을의  부분을, 에 대한 내용은  문서를의 번 문단을의 번 문단을의  부분을의  부분을 참고하십시오.유상철의 감독직 및 기타 직책 ▼둘러보기 틀 모음대표팀클럽대전 시티즌6대전남 드래곤즈12대인천 Utd9대 대한민국 축구 국가대표팀 주장    홍명보(1998~2002)▶ 유상철(2002~2005) ▶ 이운재(2005~2006)둘러보기 틀 모음대표팀클럽대전 시티즌6대전남 드래곤즈12대인천 Utd9대 대한민국 축구 국가대표팀 주장    홍명보(1998~2002)▶ 유상철(2002~2005) ▶ 이운재(2005~2006)유상철의 수상 이력 ▼둘러보기 틀 모음팀 수상개인 수상베스트팀2002 FIFA 월드컵대한민국 축구 국가대표팀 FIFA 센츄리 클럽 가입 선수  [ 펼치기 · 접기 ]순위선수 이름 /  현재 소속팀출전 횟수첫 경기마지막 경기1홍명보은퇴136회1990.02.04 (vs 노르웨이)2002.11.20(vs 브라질)2이운재은퇴131회1994.06.11 (vs 온두라스)2010.08.11(vs 나이지리아)3차범근은퇴130회1972.05.07 (vs 이라크)1986.06.10(vs 이탈리아)4이영표은퇴127회1999.06.12 (vs 멕시코)2011.01.28(vs 우즈베키스탄)5유상철은퇴120회1994.09.11 (vs 우크라이나)2005.06.03(vs 우즈베키스탄)6김호곤은퇴117회1971.10.04 (vs 대만)1979.03.04(vs 일본)7기성용FC 서울110회2008.09.05 (vs 요르단)2019.01.07(vs 필리핀)8김태영은퇴104회1992.10.21 (vs UAE)2004.07.19(vs 요르단)이동국은퇴104회1998.05.16 (vs 자메이카)2017.09.05(vs 우즈베키스탄) 10조영증은퇴102회1975.03.19 (vs 베트남)1986.10.05(vs 사우디아라비아)황선홍은퇴102회1988.12.06 (vs 일본)2002.11.20(vs 브라질)12박성화은퇴101회1975.07.29 (vs 말레이시아)1984.12.10(vs 카타르)13박지성은퇴100회2000.04.05 (vs 라오스)2011.01.25(vs 일본)※ FIFA 센추리 클럽 명단 기준 (2020.06.30 Ver.) ※ FIFA에서 공인한 기록과 대한축구협회에서 집계한 기록은 차이가 있다. 대한축구협회 선수별 A매치 기록실 참고.  득점왕1997년→1998년→1999년김현석(울산 현대 호랑이)→유상철(울산 현대 호랑이)→샤샤(수원 삼성 블루윙즈)1994 K리그 베스트 일레븐 FW  윤상철FW  라데FW  김경래MF  신태용MF  고정운MF  황보관DF  안익수DF  허기태DF  홍명보DF  유상철GK  사리체프1998 K리그 베스트 일레븐 FW  김현석FW  샤샤MF  고종수MF  유상철MF  백승철MF  안정환MF  정정수DF  안익수DF  마시엘DF  이임생GK  김병지2002 K리그 베스트 일레븐 FW  김대의FW  유상철MF  신태용MF  이천수MF  안드레MF  서정원DF  김현수DF  김태영DF  최진철DF  홍명보GK  이운재 K리그 30주년 레전드 베스트 XI    FW  황선홍  FW  최순호  MF  김주성  MF  신태용  MF  유상철  MF  서정원  DF  최강희  DF  김태영  DF  홍명보  DF  박경훈  GK  신의손 둘러보기 틀 모음팀 수상개인 수상베스트팀2002 FIFA 월드컵대한민국 축구 국가대표팀 FIFA 센츄리 클럽 가입 선수  [ 펼치기 · 접기 ]순위선수 이름 /  현재 소속팀출전 횟수첫 경기마지막 경기1홍명보은퇴136회1990.02.04 (vs 노르웨이)2002.11.20(vs 브라질)2이운재은퇴131회1994.06.11 (vs 온두라스)2010.08.11(vs 나이지리아)3차범근은퇴130회1972.05.07 (vs 이라크)1986.06.10(vs 이탈리아)4이영표은퇴127회1999.06.12 (vs 멕시코)2011.01.28(vs 우즈베키스탄)5유상철은퇴120회1994.09.11 (vs 우크라이나)2005.06.03(vs 우즈베키스탄)6김호곤은퇴117회1971.10.04 (vs 대만)1979.03.04(vs 일본)7기성용FC 서울110회2008.09.05 (vs 요르단)2019.01.07(vs 필리핀)8김태영은퇴104회1992.10.21 (vs UAE)2004.07.19(vs 요르단)이동국은퇴104회1998.05.16 (vs 자메이카)2017.09.05(vs 우즈베키스탄) 10조영증은퇴102회1975.03.19 (vs 베트남)1986.10.05(vs 사우디아라비아)황선홍은퇴102회1988.12.06 (vs 일본)2002.11.20(vs 브라질)12박성화은퇴101회1975.07.29 (vs 말레이시아)1984.12.10(vs 카타르)13박지성은퇴100회2000.04.05 (vs 라오스)2011.01.25(vs 일본)※ FIFA 센추리 클럽 명단 기준 (2020.06.30 Ver.) ※ FIFA에서 공인한 기록과 대한축구협회에서 집계한 기록은 차이가 있다. 대한축구협회 선수별 A매치 기록실 참고. 순위선수 이름 /  현재 소속팀출전 횟수첫 경기마지막 경기1홍명보은퇴136회1990.02.04 (vs 노르웨이)2002.11.20(vs 브라질)2이운재은퇴131회1994.06.11 (vs 온두라스)2010.08.11(vs 나이지리아)3차범근은퇴130회1972.05.07 (vs 이라크)1986.06.10(vs 이탈리아)4이영표은퇴127회1999.06.12 (vs 멕시코)2011.01.28(vs 우즈베키스탄)5유상철은퇴120회1994.09.11 (vs 우크라이나)2005.06.03(vs 우즈베키스탄)6김호곤은퇴117회1971.10.04 (vs 대만)1979.03.04(vs 일본)7기성용FC 서울110회2008.09.05 (vs 요르단)2019.01.07(vs 필리핀)8김태영은퇴104회1992.10.21 (vs UAE)2004.07.19(vs 요르단)이동국은퇴104회1998.05.16 (vs 자메이카)2017.09.05(vs 우즈베키스탄) 10조영증은퇴102회1975.03.19 (vs 베트남)1986.10.05(vs 사우디아라비아)황선홍은퇴102회1988.12.06 (vs 일본)2002.11.20(vs 브라질)12박성화은퇴101회1975.07.29 (vs 말레이시아)1984.12.10(vs 카타르)13박지성은퇴100회2000.04.05 (vs 라오스)2011.01.25(vs 일본)※ FIFA 센추리 클럽 명단 기준 (2020.06.30 Ver.) ※ FIFA에서 공인한 기록과 대한축구협회에서 집계한 기록은 차이가 있다. 대한축구협회 선수별 A매치 기록실 참고. 득점왕1997년→1998년→1999년김현석(울산 현대 호랑이)→유상철(울산 현대 호랑이)→샤샤(수원 삼성 블루윙즈)1994 K리그 베스트 일레븐 FW  윤상철FW  라데FW  김경래MF  신태용MF  고정운MF  황보관DF  안익수DF  허기태DF  홍명보DF  유상철GK  사리체프1998 K리그 베스트 일레븐 FW  김현석FW  샤샤MF  고종수MF  유상철MF  백승철MF  안정환MF  정정수DF  안익수DF  마시엘DF  이임생GK  김병지2002 K리그 베스트 일레븐 FW  김대의FW  유상철MF  신태용MF  이천수MF  안드레MF  서정원DF  김현수DF  김태영DF  최진철DF  홍명보GK  이운재 K리그 30주년 레전드 베스트 XI    FW  황선홍  FW  최순호  M ...

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비합니다.
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns=columns)

# 각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만듭니다.
for page_url in page_urls:

    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    req = scraper.get(page_url)
    html = req.content
    soup = BeautifulSoup(html, 'lxml')
    contents_table = soup.find(name="article")
    title = contents_table.find_all('h1')[0]
    
    # 카테고리 정보가 없는 경우를 확인합니다.
    if len(contents_table.find_all('ul')) > 0:
        category = contents_table.find_all('ul')[0]
    else:
        category = None
        
    content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
    content_corpus_list = []
    
    # 페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ")
    else:
        row_title = ""
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
        
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
    
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
print(df.shape)
df.head(10)
# Out:
# (80, 3)
#                                   title  \
# 0                                  유상철
# 1  2022 FIFA 월드컵 카타르/지역예선(아시아)/2차예선/B조
# 2                       KBO 올스타전/2021년
# 3                            라돈(몬스터버스)
# 4                                  노홍철
# 5                     Rewind : Blossom
# 6                         휴지통:27153962
# 7                        블랙펄(캐리비안의 해적)
# 8                               경제 비타민
# 9                     수도권 전철 1호선/운행 계통
#
#                                             category  \
# 0  1971년 출생1994년 데뷔2021년 사망췌장암으로 죽은 인물은평구 출신 인물문화...
# 1                                  2022 FIFA 월드컵 카타르
# 2                                           KBO 올스타전
# 3                                       고지라 시리즈몬스터버스
# 4                                                노홍철
# 5      2021년 음반다비치어반자카파B1A4의 음반EXO/음반NCT/음반IZ*ONE/음반
# 6
# 7                                       캐리비안의 해적 시리즈
# 8                        KBS 예능2006년 방송 프로그램2008년 종영
# 9                                         수도권 전철 1호선
#
#                                         content_text
# 0     은(는) 여기로 연결됩니다. 정치인에 대한 내용은 류상철 문서를의 번 문단을의...
# 1     상위 문서: 2022 FIFA 월드컵 카타르/지역예선(아시아)/2차예선 202...
# 2     상위 문서: KBO 올스타전 역대 프로야구 올스타전2020 KBO 언택트 올스...
# 3  이 문서에 스포일러가 포함되어 있습니다.이 문서가 설명하는 작품이나 인물 등에 대한...
# 4  노홍철의 관련 둘러보기 틀 [ 펼치기 · 접기 ] [ 소속 아티스트 ]방송인유재석정...
# 5  Rewind : Blossom 3월 12일 커버3월 26일 커버발매일 2021년 3...
# 6
# 7  1. 개요2. 상세3. 과거4. 시리즈4.1. 캐리비안의 해적: 블랙 펄의 저주4....
# 8  경제 비타민ECONOMY VITAMIN장르경제 전문 예능방송 채널KBS 2TV방송 ...
# 9     상위 문서: 수도권 전철 1호선 수도권 전철 1호선 [ 펼치기 · 접기 ]경원...

# %% [markdown]
# ### Step 2 : keywords 추출

# %%
## 텍스트에서 한글이 아닌것은 모두 제거 
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text)
    return result


#text_cleaning(df['content_text'][0])
#text_cleaning(df['content_text'][1])
text_cleaning(df['content_text'][2])
# Out:
# '  상위 문서  올스타전 역대 프로야구 올스타전  언택트 올스타 레이스  올스타전  올스타전 올스타전 로고날짜년 월 일개최지서울특별시 고척 스카이돔테마테마명주최후원신한은행 협찬인터파크 주관방송사 홈페이지 올스타전 공식 홈페이지 개요 일정 구단별 후보 명단    리그 주년 및 년 올스타전 이후로 년 만에 고척 스카이돔에서 열리는   올스타전이다년 월 일에 홈런 더비와 올스타전 본 경기가 개최된다  구단별 후보 명단 드림 올스타 구분  투수  포수  내야수  외야수  지명타자  선발  중간  마무리  루수  루수  루수  유격수    두산  최원준  이승진  김강률  장승현  양석환  강승호  허경민  김재호  김재환  박건우  김인태  페르난데스      배제성  김민수  김재윤  장성우  강백호  박경수  황재균  심우준  알몬테  배정대  조용호  유한준    롯데  스트레일리  구승민  김원중  지시완  이대호  안치홍  한동희  마차도  전준우  정훈  손아섭  나승엽    삼성  원태인  우규민  오승환  강민호  오재일  김상수  이원석  김지찬  김헌곤  박해민  구자욱  피렐라      문승원  김태훈  서진용  이재원  로맥  최주환  최정  박성한  최지훈  추신수  한유섬  정의윤  구단별 후보 명단 나눔 올스타  구분  투수  포수  내야수  외야수  지명타자  선발  중간  마무리  루수  루수  루수  유격수      루친스키  임정호  원종현  양의지  강진성  박민우  박석민  노진혁  이명기  알테어  나성범  권희동      수아레즈  정우영  고우석  유강남  라모스  정주현  김민성  오지환  김현수  홍창기  이천웅  채은성    키움  요키시  김성민  조상우  박동원  박병호  서건창  전병우  김혜성  이용규  이정후  송우현  김웅빈      브룩스  이승재  정해영  한승택  류지혁  김선빈  김태진  박찬호  최원준  이창진  터커  최형우    한화  카펜터  강재민  정우람  최재훈  힐리  정은원  노시환  하주석  정진호  장운호  김민하  이성열 지난해와 마찬가지로 선수단 투표 없이 팬 투표 로 결정된다'

# %%
## 클리닝 함수를 다른 모든 변수들에도 적용 
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))

df.head()
# Out:
#                    title                                           category  \
# 0                   유상철   년 출생년 데뷔년 사망췌장암으로 죽은 인물은평구 출신 인물문화 류씨경신고등학교서울 ...
# 1    월드컵 카타르지역예선아시아차예선조                                             월드컵 카타르
# 2                 올스타전년                                                올스타전
# 3               라돈몬스터버스                                        고지라 시리즈몬스터버스
# 4                   노홍철                                                 노홍철
#
#                                         content_text
# 0    은는 여기로 연결됩니다 정치인에 대한 내용은 류상철 문서를의 번 문단을의  부분...
# 1    상위 문서   월드컵 카타르지역예선아시아차예선   월드컵 카타르 지역예선  펼치...
# 2    상위 문서  올스타전 역대 프로야구 올스타전  언택트 올스타 레이스  올스타전 ...
# 3  이 문서에 스포일러가 포함되어 있습니다이 문서가 설명하는 작품이나 인물 등에 대한 ...
# 4  노홍철의 관련 둘러보기 틀  펼치기  접기   소속 아티스트 방송인유재석정형돈노홍철...

# %%
## 말뭉치 만들기 
title_corpus = "".join(df['title'].tolist())
category_corpus = "".join(df['category'].tolist())
content_corpus = "".join(df['content_text'].tolist())

title_corpus
# Out:
# '유상철   월드컵 카타르지역예선아시아차예선조  올스타전년 라돈몬스터버스 노홍철    휴지통 블랙펄캐리비안의 해적 경제 비타민 수도권 전철 호선운행 계통 뱃신 파일 후도 유세이 설리 사망 사건 카닐리언명일방주 카데바 갤럭시  시리즈년 대한민국 해병대악습 다주 안내방송 트리플 크라운 에나 세츠나  푸리케츠 카게로우 프로젝트 너무아퍼  미나토 아쿠아 로제 베트남 공안부 휴지통 히로인은 절망했습니다 이클립스 건담 템플릿인터넷 방송인 페루 파일 서초구 을 의용소방대 유상철생애 강다니엘 수원  스카이뷰 틀실버리오 사가설정 레그넌트 더 킹 오브 파이터즈  세종교통 뽀롱뽀롱 뽀로로방영목록 공동주택목록김해시 가면라이더 세이버 한국의 성씨 군국주의 텔레마케터 항공관광과 브랜든웹툰   버프 및 디버프 치코리타 시체 호위기 아마이아 살라망카 칸나이 전투 대한민국의 여성인권단체목록    무기 해기님  뉴스룸 자낳대역대 우승팀 볼드퍼스 선택받은 소년     가디언 테일즈모험 김성대 틀 바르셀로나 휴지통 휴지통 해부실습 존나아퍼 콩콩 파주출판도시   월드컵 카타르지역예선아시아차예선조 세종 버스  삼국지 평가   마르코스 마이다나 미추리  광종고려 '

# %%
# !pip install konlpy==0.5.1
# Out:
# Collecting konlpy==0.5.1
#   Using cached konlpy-0.5.1-py2.py3-none-any.whl (19.4 MB)
# Requirement already satisfied: JPype1>=0.5.7 in c:\users\youngboo.choi\anaconda3.1\lib\site-packages (from konlpy==0.5.1) (1.2.1)
# ERROR: Could not install packages due to an OSError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\youngboo.choi\\Anaconda3.1\\Lib\\site-packages\\konlpy\\java\\aho-corasick.jar'
# Consider using the `--user` option or check the permissions.
# Installing collected packages: konlpy

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(content_corpus)
count = Counter(nouns)
count
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-19-d36913e495f4> in <module>
#       1 # konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
# ----> 2 nouns_tagger = Okt()
#       3 nouns = nouns_tagger.nouns(content_corpus)
#       4 count = Counter(nouns)
#       5 count
#
# ~\Anaconda3.1\lib\site-packages\konlpy\tag\_okt.py in __init__(self, jvmpath, max_heap_size)
#      89     def __init__(self, jvmpath=None, max_heap_size=1024):
#      90         if not jpype.isJVMStarted():
# ---> 91             jvm.init_jvm(jvmpath, max_heap_size)
#      92
#      93         oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#
# ~\Anaconda3.1\lib\site-packages\konlpy\jvm.py in init_jvm(jvmpath, max_heap_size)
#      62
#      63     if jvmpath:
# ---> 64         jpype.startJVM(jvmpath, '-Djava.class.path=%s' % classpath,
#      65                                 '-Dfile.encoding=UTF8',
#      66                                 '-ea', '-Xmx{}m'.format(max_heap_size))
#
# ~\Anaconda3.1\lib\site-packages\jpype\_core.py in startJVM(*args, **kwargs)
#     219
#     220     try:
# --> 221         _jpype.startup(jvmpath, tuple(args),
#     222                        ignoreUnrecognized, convertStrings, interrupt)
#     223         initializeResources()
#
# SystemError: java.nio.file.InvalidPathException: Illegal char <*> at index 65: C:\Users\youngboo.choi\Anaconda3.1\Lib\site-packages\konlpy\java\*
