# %%
## About sciket-learn  
from IPython.display import Image
Image(url= "https://scikit-learn.org/stable/_static/ml_map.png")
# Out:
# <img src="https://scikit-learn.org/stable/_static/ml_map.png"/>

# %%
## Model Evaluations (https://bkshin.tistory.com/entry/%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D-17-%ED%9A%8C%EA%B7%80-%ED%8F%89%EA%B0%80-%EC%A7%80%ED%91%9C)
from IPython.display import Image
Image("img/model evaluation.png")

# %%
## K Fold cross calidation
from IPython.display import Image
Image("img/cross_v.png")
